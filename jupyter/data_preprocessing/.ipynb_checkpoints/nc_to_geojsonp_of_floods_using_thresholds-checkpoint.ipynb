# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    """
    Turn a dataframe containing point data into a geojson formatted python dictionary
    
    df : the dataframe to convert to geojson
    properties : a list of columns in the dataframe to turn into geojson feature properties
    lat : the name of the column in the dataframe that contains latitude data
    lon : the name of the column in the dataframe that contains longitude data
    """
    
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in df.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %%
#Step 1.Convert xarray to pandas dataframe

# %%
import xarray as xr

# %%
sample_day = xr.open_dataset("/Volumes/portableHardDisk/data/glofas/2019/CEMS_ECMWF_dis24_20190105_glofas_v2.1.nc")

# %%
sample_threshold = xr.open_dataset('/Volumes/portableHardDisk/data/thresholds/2year.nc')

# %%
sample_day['dis24'].plot()

# %%
mask = sample_day['dis24'] > sample_threshold['Band1']

# %%
mask.plot()

# %%
sample_day = sample_day.where(mask, drop=True)

# %%
sample_day['dis24'].plot()

# %%
df = sample_day["dis24"].to_dataframe()

# %%
df = df[df['dis24'].notna()]

# %%
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['time', 'lat', 'lon', 'dis24'], dtype='object')

# %%
geojson_dict = df_to_geojson(df, properties=['dis24', "lat", "lon"], lat='lat', lon="lon");

# %%
geojson_dict
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'dis24': 16.643328648695462,
#     'lat': 36.849998474121094,
#     'lon': 38.54999923706055},
#    'geometry': {'type': 'Point',
#     'coordinates': [38.54999923706055, 36.849998474121094]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 18.11016151604086,
#     'lat': 36.75,
#     'lon': 38.650001525878906},
#    'geometry': {'type': 'Point', 'coordinates': [38.650001525878906, 36.75]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 20.625994174857087,
#     'lat': 36.650001525878906,
#     'lon': 38.75},
#    'geometry': {'type': 'Point', 'coordinates': [38.75, 36.650001525878906]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 21.18205169024703,
#     'lat': 36.650001525878906,
#     'lon': 38.849998474121094},
#    'geometry': {'type': 'Point',
#     'coordinates': [38.849998474121094, 36.650001525878906]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 21.627966373496584,
#     'lat': 36.54999923706055,
#     'lon': 38.95000076293945},
#    'geometry': {'type': 'Point',
#     'coordinates': [38.95000076293945, 36.54999923706055]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 23.388816285883177,
#     'lat': 36.45000076293945,
#     'lon': 38.95000076293945},
#    'geometry': {'type': 'Point',
#     'coordinates': [38.95000076293945, 36.45000076293945]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 23.742569024991333,
#     'lat': 36.349998474121094,
#     'lon': 38.95000076293945},
#    'geometry': {'type': 'Point',
#     'coordinates': [38.95000076293945, 36.349998474121094]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 2.825286822600011,
#     'lat': 36.04999923706055,
#     'lon': 38.75},
#    'geometry': {'type': 'Point', 'coordinates': [38.75, 36.04999923706055]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3508896424514607,
#     'lat': 34.150001525878906,
#     'lon': 39.95000076293945},
#    'geometry': {'type': 'Point',
#     'coordinates': [39.95000076293945, 34.150001525878906]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3722885355502884,
#     'lat': 34.04999923706055,
#     'lon': 39.75},
#    'geometry': {'type': 'Point', 'coordinates': [39.75, 34.04999923706055]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3708631671359409,
#     'lat': 34.04999923706055,
#     'lon': 39.849998474121094},
#    'geometry': {'type': 'Point',
#     'coordinates': [39.849998474121094, 34.04999923706055]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0
}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3835850464381412,
#     'lat': 31.049999237060547,
#     'lon': 42.349998474121094},
#    'geometry': {'type': 'Point',
#     'coordinates': [42.349998474121094, 31.049999237060547]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3480157320540384,
#     'lat': 30.950000762939453,
#     'lon': 42.25},
#    'geometry': {'type': 'Point', 'coordinates': [42.25, 30.950000762939453]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3285431753030319,
#     'lat': 30.850000381469727,
#     'lon': 42.150001525878906},
#    'geometry': {'type': 'Point',
#     'coordinates': [42.150001525878906, 30.850000381469727]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.3104260687068802,
#     'lat': 30.75,
#     'lon': 42.150001525878906},
#    'geometry': {'type': 'Point', 'coordinates': [42.150001525878906, 30.75]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.2936557233333635, 'lat': 30.75, 'lon': 42.25},
#    'geometry': {'type': 'Point', 'coordinates': [42.25, 30.75]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.28848858354713025,
#     'lat': 30.649999618530273,
#     'lon': 42.25},
#    'geometry': {'type': 'Point', 'coordinates': [42.25, 30.649999618530273]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.2840590392884198,
#     'lat': 30.549999237060547,
#     'lon': 42.150001525878906},
#    'geometry': {'type': 'Point',
#     'coordinates': [42.150001525878906, 30.549999237060547]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.04290598926041638,
#     'lat': 30.25,
#     'lon': 46.650001525878906},
#    'geometry': {'type': 'Point', 'coordinates': [46.650001525878906, 30.25]}},
#   {'type': 'Feature',
#    'properties': {'dis24': 0.19013498022506117,
#     'lat': 30.149999618530273,
#     'lon': 46.650001525878906},
#    'geometry': {'type': 'Point',
#     'coordinates': [46.650001525878906, 30.149999618530273]}}]}

# %%
import json
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
time = df['time'][0].strftime("%m-%d-%Y")

# %%
time
# Out:
# '01-05-2019'

# %%
 # save the geojson result to a file
output_filename = '/Volumes/portableHardDisk/data/geojsonp/'+ time + '.geojsonp'
with open(output_filename, 'w') as output_file:
    output_file.write('eqfeed_callback({})'.format(geojson_str))

# %%
i = str(301)
i.zfill(2)
# Out:
# '301'

# %%
#Do this for a month at a global scale 
import json
sample_threshold = xr.open_dataset('/Volumes/portableHardDisk/data/thresholds/20year.nc')
for i in range(1,31):
    i = str(i).zfill(2)
    sample_day = xr.open_dataset("/Volumes/portableHardDisk/data/glofas/2013/CEMS_ECMWF_dis24_201305"+ i +"_glofas_v2.1.nc")
    sample_day = sample_day.where((sample_day['dis24'] > sample_threshold['Band1']), drop=True)
    df = sample_day["dis24"].to_dataframe()
    df = df[df['dis24'].notna()]
    df.reset_index(inplace=True)  
    geojson_dict = df_to_geojson(df, properties=['dis24', "lat", "lon"], lat='lat', lon="lon")
    geojson_str = json.dumps(geojson_dict, indent=2)
    time = df['time'][0].strftime("%m-%d-%Y")
    output_filename = '/Volumes/portableHardDisk/data/geojsonp/2year/'+ time + '.geojsonp'
    with open(output_filename, 'w') as output_file:
        output_file.write('eqfeed_callback({})'.format(geojson_str))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-b0d63fda076f> in <module>
#       5     i = str(i).zfill(2)
#       6     sample_day = xr.open_dataset("/Volumes/portableHardDisk/data/glofas/2013/CEMS_ECMWF_dis24_201305"+ i +"_glofas_v2.1.nc")
# ----> 7     sample_day = sample_day.where((sample_day['dis24'] > sample_threshold['Band1']), drop=True)
#       8     df = sample_day["dis24"].to_dataframe()
#       9     df = df[df['dis24'].notna()]
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/dataarray.py in func(self, other)
#    2573             variable = (
#    2574                 f(self.variable, other_variable)
# -> 2575                 if not reflexive
#    2576                 else f(other_variable, self.variable)
#    2577             )
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/variable.py in func(self, other)
#    1967             if isinstance(other, (xr.DataArray, xr.Dataset)):
#    1968                 return NotImplemented
# -> 1969             self_data, other_data, dims = _broadcast_compat_data(self, other)
#    1970             keep_attrs = _get_keep_attrs(default=False)
#    1971             attrs = self._attrs if keep_attrs else None
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/variable.py in _broadcast_compat_data(self, other)
#    2268         # `other` satisfies the necessary Variable API for broadcast_variables
#    2269         new_self, new_other = _broadcast_compat_variables(self, other)
# -> 2270         self_data = new_self.data
#    2271         other_data = new_other.data
#    2272         dims = new_self.dims
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/variable.py in data(self)
#     341             return self._data
#     342         else:
# --> 343             return self.values
#     344
#     345     @data.setter
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/variable.py in values(self)
#     446     def values(self):
#     447         """The variable's data as a numpy.ndarray"""
# --> 448         return _as_array_or_item(self._data)
#     449
#     450     @values.setter
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     252     TODO: remove this (replace with np.asarray) once these issues are fixed
#     253     """
# --> 254     data = np.asarray(data)
#     255     if data.ndim == 0:
#     256         if data.dtype.kind == "M":
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     665
#     666     def __array__(self, dtype=None):
# --> 667         self._ensure_cached()
#     668         return np.asarray(self.array, dtype=dtype)
#     669
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/indexing.py in _ensure_cached(self)
#     662     def _ensure_cached(self):
#     663         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 664             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     665
#     666     def __array__(self, dtype=None):
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     641
#     642     def __array__(self, dtype=None):
# --> 643         return np.asarray(self.array, dtype=dtype)
#     644
#     645     def __getitem__(self, key):
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     545     def __array__(self, dtype=None):
#     546         array = as_indexable(self.array)
# --> 547         return np.asarray(array[self.key], dtype=None)
#     548
#     549     def transpose(self, order):
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      70
#      71     def __array__(self, dtype=None):
# ---> 72         return self.func(self.array)
#      73
#      74     def __repr__(self):
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     136 ) -> np.ndarray:
#     137     """Mask all matching values in a NumPy arrays."""
# --> 138     data = np.asarray(data, dtype=dtype)
#     139     condition = False
#     140     for fv in encoded_fill_values:
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     545     def __array__(self, dtype=None):
#     546         array = as_indexable(self.array)
# --> 547         return np.asarray(array[self.key], dtype=None)
#     548
#     549     def transpose(self, order):
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      70     def __getitem__(self, key):
#      71         return indexing.explicit_indexing_adapter(
# ---> 72             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#      73         )
#      74
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     825     """
#     826     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 827     result = raw_indexing_method(raw_key.tuple)
#     828     if numpy_indices.tuple:
#     829         # index the loaded np.ndarray
#
# /opt/miniconda3/envs/flood_prediction/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#      82             with self.datastore.lock:
#      83                 original_array = self.get_array(needs_lock=False)
# ---> 84                 array = getitem(original_array, key)
#      85         except IndexError:
#      86             # Catch IndexError in netCDF4 and return a more informative
#
# KeyboardInterrupt:

# %%
df
# Out:
#            time    lat    lon         dis24
# 0    2019-01-02  69.75  84.75  10120.081055
# 1    2019-01-02  69.75  84.85  10114.541016
# 2    2019-01-02  69.75  84.95  10110.479492
# 3    2019-01-02  69.75  85.05  10106.587891
# 4    2019-01-02  69.75  85.15  10102.459961
# ...         ...    ...    ...           ...
# 2843 2019-01-02 -33.85 -58.95  10554.273438
# 2844 2019-01-02 -33.95 -58.85  10573.445312
# 2845 2019-01-02 -33.95 -58.75  10586.578125
# 2846 2019-01-02 -33.95 -58.65  10593.579102
# 2847 2019-01-02 -33.95 -58.55  10610.449219
#
# [2848 rows x 4 columns]
